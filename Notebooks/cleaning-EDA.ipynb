# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")

df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
print("--- Initial Data Check ---")
print(df.info())
# Out:
# --- Initial Data Check ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
print("\nMissing values per column:\n", df.isnull().sum())
# Out:
# Missing values per column:
#  battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
# 3. REMOVE DUPLICATES
# ==========================================
duplicate_count = df.duplicated().sum()
print(f"\nRemoving {duplicate_count} duplicate rows...")
df = df.drop_duplicates()
# Out:
# Removing 0 duplicate rows...

# %%
# to check for unique values in each column
df.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %%
# to check for outliers


df.boxplot(figsize=(15,6))
plt.xticks(rotation=90)
plt.show()

# %%
df.boxplot(figsize=(15,6), column='fc')
plt.xticks(rotation=90)
plt.show()

# %%
print(df.groupby('price_range')['fc'].describe())
# Out:
#              count   mean       std  min  25%  50%  75%   max
# price_range
# 0            500.0  4.084  4.183772  0.0  1.0  3.0  6.0  19.0
# 1            500.0  4.340  4.499432  0.0  1.0  3.0  7.0  18.0
# 2            500.0  4.498  4.347390  0.0  1.0  3.0  7.0  18.0
# 3            500.0  4.316  4.332399  0.0  1.0  3.0  7.0  18.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(24,16))
sns.heatmap(data = df.corr(), annot = True, cmap = "Blues",)
plt.show()


# The "Fishy" Part: Market Logic FailureLook closely at the max values across your groupby categories:price_range 0 (Cheapest Phones): Maximum front camera is 19.0 MPprice_range 3 (Most Expensive Luxury Phones): Maximum front camera is 18.0 MP
# now since fc has 0.022 correlation with price_range, it is not a strong indicator of price_range. But the fact that the maximum front camera for the cheapest phones is higher than the maximum front camera for the most expensive phones is a market logic failure. This is a red flag that there may be some data quality issues in this dataset.

# %%
df[(df["three_g"] == 0) & (df["four_g"] == 1)]
# to  check if there are any rows where both three_g and four_g are 1, which is not possible
# Out:
# Empty DataFrame
# Columns: [battery_power, blue, clock_speed, dual_sim, fc, four_g, int_memory, m_dep, mobile_wt, n_cores, pc, px_height, px_width, ram, sc_h, sc_w, talk_time, three_g, touch_screen, wifi, price_range]
# Index: []
#
# [0 rows x 21 columns]

# %%
# check constant columns

for col in df.columns:
    print(col, df[col].nunique())
# Out:
# battery_power 1094
# blue 2
# clock_speed 26
# dual_sim 2
# fc 20
# four_g 2
# int_memory 63
# m_dep 10
# mobile_wt 121
# n_cores 8
# pc 21
# px_height 1137
# px_width 1109
# ram 1562
# sc_h 15
# sc_w 19
# talk_time 19
# three_g 2
# touch_screen 2
# wifi 2
# price_range 4

# %%
#Save your finalized dataset
df.to_csv('test_cleaned.csv', index=False)
print("\nData cleaning complete and saved to 'test_cleaned.csv'!")
# Out:
# Data cleaning complete and saved to 'test_cleaned.csv'!
