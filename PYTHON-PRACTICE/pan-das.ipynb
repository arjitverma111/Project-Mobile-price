# %%
import pandas as pd
import numpy as np
import random
df = pd.DataFrame(
          {"a" : [4, 5, 6], 
           "b" : [7, 8, 9], 
           "c" : [10, 11, 12]},    
        index = [1, 4, 3])

# %%
print(df)
# Out:
#    a  b   c
# 1  4  7  10
# 4  5  8  11
# 3  6  9  12

# %%
# converts columns into rows 

pd.melt(df)
# Out:
#   variable  value
# 0        a      4
# 1        a      5
# 2        a      6
# 3        b      7
# 4        b      8
# 5        b      9
# 6        c     10
# 7        c     11
# 8        c     12

# %%
df.reset_index()
# Out:
#    index  a  b   c
# 0      1  4  7  10
# 1      4  5  8  11
# 2      3  6  9  12

# %%
#select first n rows
df.head(2)
# Out:
#    a  b   c
# 1  4  7  10
# 4  5  8  11

# %%
#select last n rows

df.tail(1)
# Out:
#    a  b   c
# 3  6  9  12

# %%
df.index = ["r1", "r2", "r3"]

print(df)
# Out:
#     a  b   c
# r1  4  7  10
# r2  5  8  11
# r3  6  9  12

# %%
x = pd.DataFrame(np.random.rand(233, 10))

print(x)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.766294  0.435558  0.283841  0.828098  0.040926  0.646360  0.160850
# 1    0.242638  0.816780  0.075306  0.986326  0.794634  0.727749  0.323177
# 2    0.632468  0.246131  0.000598  0.846768  0.315080  0.368923  0.692655
# 3    0.001362  0.648214  0.200873  0.834739  0.636913  0.379975  0.668940
# 4    0.449318  0.745140  0.756124  0.860459  0.191523  0.757239  0.773601
# ..        ...       ...       ...       ...       ...       ...       ...
# 228  0.552071  0.385082  0.105683  0.673579  0.490351  0.973062  0.545741
# 229  0.774753  0.204672  0.595179  0.140651  0.126586  0.631514  0.415223
# 230  0.712323  0.453787  0.853857  0.104693  0.410830  0.610200  0.808740
# 231  0.738369  0.498723  0.484452  0.675534  0.887935  0.081246  0.746730
# 232  0.141114  0.715767  0.660025  0.499658  0.020076  0.267658  0.637170
#
#             7         8         9
# 0    0.611817  0.831040  0.238822
# ...

# %%
#gives the rows with smallest value in the soecified column, automatically sorts the rows 
# for eg give me 3 rows with smallest value in column 7
(x.nsmallest(3,[7]))
# Out:
#             0         1         2         3         4         5         6  \
# 101  0.821462  0.278664  0.261955  0.015668  0.048248  0.182267  0.564821
# 187  0.375746  0.212852  0.200873  0.461776  0.726559  0.198600  0.577559
# 12   0.191897  0.923683  0.952034  0.766723  0.200676  0.068612  0.305203
#
#             7         8         9
# 101  0.003251  0.367752  0.366931
# 187  0.004884  0.326059  0.380204
# 12   0.016912  0.748827  0.383976

# %%
print(x.columns)
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
x.to_csv("random.csv")

# %%
x.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  233.000000  233.000000  233.000000  233.000000  233.000000  233.000000
# mean     0.497649    0.514488    0.492922    0.511824    0.483136    0.508577
# std      0.269737    0.292549    0.290705    0.286195    0.285578    0.281039
# min      0.001362    0.009512    0.000598    0.000439    0.020076    0.002285
# 25%      0.285006    0.256175    0.251480    0.267506    0.235280    0.284854
# 50%      0.482503    0.516073    0.468985    0.524263    0.485757    0.525235
# 75%      0.726521    0.780151    0.737127    0.764895    0.712319    0.739422
# max      0.987834    0.999498    0.996586    0.992126    0.995856    0.994679
#
#                 6           7           8           9
# count  233.000000  233.000000  233.000000  233.000000
# mean     0.515049    0.519834    0.500496    0.506665
# std      0.289522    0.299981    0.289458    0.279543
# ...

# %%
hehe = pd.read_csv("random.csv")
print(hehe)
# Out:
#      Unnamed: 0         0         1         2         3         4         5  \
# 0             0  0.766294  0.435558  0.283841  0.828098  0.040926  0.646360
# 1             1  0.242638  0.816780  0.075306  0.986326  0.794634  0.727749
# 2             2  0.632468  0.246131  0.000598  0.846768  0.315080  0.368923
# 3             3  0.001362  0.648214  0.200873  0.834739  0.636913  0.379975
# 4             4  0.449318  0.745140  0.756124  0.860459  0.191523  0.757239
# ..          ...       ...       ...       ...       ...       ...       ...
# 228         228  0.552071  0.385082  0.105683  0.673579  0.490351  0.973062
# 229         229  0.774753  0.204672  0.595179  0.140651  0.126586  0.631514
# 230         230  0.712323  0.453787  0.853857  0.104693  0.410830  0.610200
# 231         231  0.738369  0.498723  0.484452  0.675534  0.887935  0.081246
# 232         232  0.141114  0.715767  0.660025  0.499658  0.020076  0.267658
#
#             6         7         8         9
# ...

# %%
# dataframes are collection of series

# %%
ser = pd.Series(np.random.rand(5))

print(ser)
# Out:
# 0    0.421829
# 1    0.061485
# 2    0.970624
# 3    0.633633
# 4    0.331320
# dtype: float64

# %%
#when we are chaining , we use loc  
#x[0][0] = 12345
x.loc[0,0] = 12345

x.head(3)
# Out:
#               0         1         2         3         4         5         6  \
# 0  12345.000000  0.435558  0.283841  0.828098  0.040926  0.646360  0.160850
# 1      0.242638  0.816780  0.075306  0.986326  0.794634  0.727749  0.323177
# 2      0.632468  0.246131  0.000598  0.846768  0.315080  0.368923  0.692655
#
#           7         8         9
# 0  0.611817  0.831040  0.238822
# 1  0.317992  0.272217  0.567238
# 2  0.844251  0.543303  0.273486

# %%
x.columns = list("ABCDEFGHIJ")

x.head(3)
# Out:
#               A         B         C         D         E         F         G  \
# 0  12345.000000  0.435558  0.283841  0.828098  0.040926  0.646360  0.160850
# 1      0.242638  0.816780  0.075306  0.986326  0.794634  0.727749  0.323177
# 2      0.632468  0.246131  0.000598  0.846768  0.315080  0.368923  0.692655
#
#           H         I         J
# 0  0.611817  0.831040  0.238822
# 1  0.317992  0.272217  0.567238
# 2  0.844251  0.543303  0.273486

# %%
x.loc[(x['A'] < 0.5) & (x['B'] > 0.5)]
# Out:
#             A         B         C         D         E         F         G  \
# 1    0.242638  0.816780  0.075306  0.986326  0.794634  0.727749  0.323177
# 3    0.001362  0.648214  0.200873  0.834739  0.636913  0.379975  0.668940
# 4    0.449318  0.745140  0.756124  0.860459  0.191523  0.757239  0.773601
# 5    0.177701  0.567224  0.400021  0.087922  0.374508  0.745597  0.495868
# 12   0.191897  0.923683  0.952034  0.766723  0.200676  0.068612  0.305203
# 13   0.110762  0.995140  0.016258  0.400148  0.338919  0.892545  0.278289
# 14   0.143157  0.985945  0.659021  0.267506  0.995280  0.744626  0.102301
# 26   0.486961  0.672436  0.830768  0.298545  0.257538  0.898203  0.645503
# 28   0.278715  0.768504  0.713365  0.081743  0.075073  0.776019  0.901783
# 33   0.188006  0.699006  0.681518  0.156845  0.921012  0.979313  0.478091
# 38   0.400972  0.749782  0.548075  0.001821  0.376754  0.633247  0.024844
# 40   0.305319  0.812812  0.193024  0.551383  0.244836  0.624301  0.457268
# ...

# %%
 # use iloc if you want to select by position

x.iloc[0,0]

# used [0,0] in place of [0,A]
# Out:
# 12345.0

# %%
x.iloc[[1,5],[2,5]]
# Out:
#           C         F
# 1  0.075306  0.727749
# 5  0.400021  0.745597

# %%
# use inplace = True to make changes in the original dataframe instead of creating a new one

# %%
x.reset_index(drop = True, inplace = True)   # resets index and drops the old index column

# %%
x['A'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 228    False
# 229    False
# 230    False
# 231    False
# 232    False
# Name: A, Length: 233, dtype: bool

# %%
x.dropna(how = 'all') # drops rows where all values are null

# don't forget that it creates a copy, original x is not changed
# Out:
#                 A         B         C         D         E         F         G  \
# 0    12345.000000  0.435558  0.283841  0.828098  0.040926  0.646360  0.160850
# 1        0.242638  0.816780  0.075306  0.986326  0.794634  0.727749  0.323177
# 2        0.632468  0.246131  0.000598  0.846768  0.315080  0.368923  0.692655
# 3        0.001362  0.648214  0.200873  0.834739  0.636913  0.379975  0.668940
# 4        0.449318  0.745140  0.756124  0.860459  0.191523  0.757239  0.773601
# ..            ...       ...       ...       ...       ...       ...       ...
# 228      0.552071  0.385082  0.105683  0.673579  0.490351  0.973062  0.545741
# 229      0.774753  0.204672  0.595179  0.140651  0.126586  0.631514  0.415223
# 230      0.712323  0.453787  0.853857  0.104693  0.410830  0.610200  0.808740
# 231      0.738369  0.498723  0.484452  0.675534  0.887935  0.081246  0.746730
# 232      0.141114  0.715767  0.660025  0.499658  0.020076  0.267658  0.637170
#
# ...

# %%
x.drop_duplicates(subset = ['A'])   # drops the rows where column A has null values
# Out:
#                 A         B         C         D         E         F         G  \
# 0    12345.000000  0.435558  0.283841  0.828098  0.040926  0.646360  0.160850
# 1        0.242638  0.816780  0.075306  0.986326  0.794634  0.727749  0.323177
# 2        0.632468  0.246131  0.000598  0.846768  0.315080  0.368923  0.692655
# 3        0.001362  0.648214  0.200873  0.834739  0.636913  0.379975  0.668940
# 4        0.449318  0.745140  0.756124  0.860459  0.191523  0.757239  0.773601
# ..            ...       ...       ...       ...       ...       ...       ...
# 228      0.552071  0.385082  0.105683  0.673579  0.490351  0.973062  0.545741
# 229      0.774753  0.204672  0.595179  0.140651  0.126586  0.631514  0.415223
# 230      0.712323  0.453787  0.853857  0.104693  0.410830  0.610200  0.808740
# 231      0.738369  0.498723  0.484452  0.675534  0.887935  0.081246  0.746730
# 232      0.141114  0.715767  0.660025  0.499658  0.020076  0.267658  0.637170
#
# ...

# %%
df.isna()
# Out:
#         a      b      c
# r1  False  False  False
# r2  False  False  False
# r3  False  False  False

# %%
df.isna().sum()  # gives the count of null values in each column
# Out:
# a    0
# b    0
# c    0
# dtype: int64

# %%
df.duplicated()
# Out:
# r1    False
# r2    False
# r3    False
# dtype: bool

# %%
df.loc[df.duplicated(subset=['a'])]


# only shows the rows which are duplicated in column a, if you want to see all the rows which are duplicated in any column, just use df.duplicated() without subset
# Out:
# Empty DataFrame
# Columns: [a, b, c]
# Index: []

# %%
# df.query('') does the same thing as df.loc[] but it is more readable and easier to use, especially when you have multiple conditions. It allows you to write your conditions in a more natural way, similar to how you would write them in SQL. For example, instead of writing df.loc[(df['A'] < 0.5) & (df['B'] > 0.5)], you can write df.query('A < 0.5 and B > 0.5'). This can make your code cleaner and easier to understand.
