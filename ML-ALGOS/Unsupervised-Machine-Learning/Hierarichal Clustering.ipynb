# %%
# no centroids
# for small datasets
# for variety of data
# if there is numerical data u can use either k means or hierarchical

# %% [markdown]
# ##### Agglomeration Clustering

# %%
# for each point intially we will consider it a a separate cluster
# find a nearest point and create a new cluster
# repeat above step until we have only one cluster left

# To find number of clusters we can use dendrogram to find the optimal number of clusters
# dendogram of distance vs point graph
# plot the dendrogram and find the longest vertical line that does not cross any horizontal line. The number of horizontal lines that intersect this vertical line is the optimal number of clusters.
