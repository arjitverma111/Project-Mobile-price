# %%
# variance = 1/n (Σ(xi - x̄)²), where x̄ is the mean of the dataset
# you check variance reduction by calculating variance 
# vairance reduction = variance_before - variance_after  
# thre split which has the less vairiance after the split is the best split  
# in dt regressor average output of the leaf node is calculated as the predicted output
