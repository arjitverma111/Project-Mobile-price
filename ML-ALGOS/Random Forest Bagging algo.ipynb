# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# Load sample dataset
iris = load_iris()
X, y = iris.data, iris.target

# Split into train/test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Train a random forest classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

#n_estimators is a hyperparameter that defines the total number of decision trees in a Random Forest model

# Predict and evaluate
y_pred = rf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# Accuracy: 0.8888888888888888
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       0.78      0.93      0.85        15
#    virginica       0.92      0.73      0.81        15
#
#     accuracy                           0.89        45
#    macro avg       0.90      0.89      0.89        45
# weighted avg       0.90      0.89      0.89        45

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.datasets import load_boston

# use iris features to predict petal width (continuous target)
X_reg = X[:, :3]   # sepal length, sepal width, petal length
y_reg = X[:, 3]    # petal width

Xr_train, Xr_test, yr_train, yr_test = train_test_split(
    X_reg, y_reg, test_size=0.3, random_state=42
)

rfr = RandomForestRegressor(n_estimators=100, random_state=42)
rfr.fit(Xr_train, yr_train)

yr_pred = rfr.predict(Xr_test)

print("MSE:", mean_squared_error(yr_test, yr_pred))
print("R2:", r2_score(yr_test, yr_pred))
boston = load_boston()
Xb, yb = boston.data, boston.target

Xb_train, Xb_test, yb_train, yb_test = train_test_split(
    Xb, yb, test_size=0.3, random_state=42
)

rfr_b = RandomForestRegressor(n_estimators=100, random_state=42)
rfr_b.fit(Xb_train, yb_train)

yb_pred = rfr_b.predict(Xb_test)

print("Boston MSE:", mean_squared_error(yb_test, yb_pred))
print("Boston R2:", r2_score(yb_test, yb_pred))
print("Feature importances:", rfr_b.feature_importances_)
# Out:
# MSE: 0.038303740881582136
# R2: 0.9398328560572746
# Boston MSE: 9.619662013157892
# Boston R2: 0.8708997131330258
# Feature importances: [0.03173083 0.00159051 0.00678511 0.00159958 0.01263682 0.43958489
#  0.01202165 0.06612009 0.00404995 0.01178936 0.019494   0.01265621
#  0.37994101]
